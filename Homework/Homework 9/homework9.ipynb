# %% [markdown]
# ### Homework 9 ###
# Continue working on the task 1 (last slide) from the lecture slides for the unit 9. Implement the classes that you designed. Test your implementation from the main program by actually using your class objects. Showing that your implementation works correctly via testing will be graded with 30% of points for this homework. Create a markdown cell with your class design and a short description of the problem and your solution. Provide your implementation with all the classes and tests as instucted below.

# %% [markdown]
# ## Your description here ##

# %%
# Your code here

# %%
# Your tests here
