# %% [markdown]
# # Running times of loops
#
# Write a small Python script to measure the running time of loops.  First, define a number $n$.  Before each loop define a counter variable and set it to zero.  In each step of the innermost loop increment the counter by 1.   After the loop has finished, print the counter.
#
# Implement the following loops:
#
# 1. **Loop A.**
#    Write a `while` loop that starts with the loop variable being equal to $n$ and runs as long as the loop variable is larger than 0.  Within the loop, integer divide (or floor divide) the loop variable by two.
#
# 2. **Loop B.**
#    Write a single `for` loop from 0 to $n - 1$.
#
# 3. **Loop C.**
#    Write a nested loop with Loop B as the outer loop and Loop A as the inner loop.
#
# 4. **Loop D.**
#    Write a nested loop with Loop B as the outer loop and Loop B as the inner loop, i.e., a nested loop with two `for` loops.
#
# 5. **Loop E.**
#    Write a nested loop with Loop D as the outer loop and Loop A as the inner loop, i.e., Loop A is enclosed in two `for` loops.
#
# 6. **Loop F.**
#    Write a nested loop with three `for` loops.
#
# ---
#
# ### **Instructions**
#
# In your code, write comments after printing the results and discuss the running times you have obtained.

# %%
import time

# Choose a value of n
n = 1000

print(f"n = {n}\n")

############################
# 1) Loop A
############################
counter_A = 0
x = n

start = time.time()

# your code here

end = time.time()

print("Loop A counter:", counter_A)
print("Loop A time:   ", end - start)
print()

# Discuss the time complexity:


############################
# 2) Loop B
############################
counter_B = 0

start = time.time()

# your code here

end = time.time()

print("Loop B counter:", counter_B)
print("Loop B time:   ", end - start)
print()

# Discuss the time complexity:


############################
# 3) Loop C (B outside, A inside)
############################
counter_C = 0

start = time.time()

# your code here

end = time.time()

print("Loop C counter:", counter_C)
print("Loop C time:   ", end - start)
print()

# Discuss the time complexity:


############################
# 4) Loop D (two for-loops)
############################
counter_D = 0

start = time.time()

# your code here

end = time.time()

print("Loop D counter:", counter_D)
print("Loop D time:   ", end - start)
print()

# Discuss the time complexity:


############################
# 5) Loop E (two for-loops outside, A inside)
############################
counter_E = 0

start = time.time()

# your code here

end = time.time()

print("Loop E counter:", counter_E)
print("Loop E time:   ", end - start)
print()

# Discuss the time complexity:

############################
# 6) Loop F (three for-loops)
############################
counter_F = 0

start = time.time()

# your code here

end = time.time()

print("Loop F counter:", counter_F)
print("Loop F time:   ", end - start)
print()

# Discuss the time complexity:
# Out:
# n = 1000
#
# Loop A counter: 0
# Loop A time:    1.9788742065429688e-05
#
# Loop B counter: 0
# Loop B time:    1.7881393432617188e-05
#
# Loop C counter: 0
# Loop C time:    1.4781951904296875e-05
#
# Loop D counter: 0
# Loop D time:    1.3828277587890625e-05
#
# Loop E counter: 0
# Loop E time:    2.09808349609375e-05
#
# Loop F counter: 0
# Loop F time:    2.002716064453125e-05
